# %% [markdown]
# ## 프로그램

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from pmdarima.arima import auto_arima
# %matplotlib inline
plt.rc('font', family = 'Malgun Gothic')
plt.rcParams['axes.unicode_minus'] = False

# %% [markdown]
# ## 데이터 불러오기

# %%
apart_time = pd.read_csv('time_series.csv', encoding = 'cp949')
apart_time['Date'] = pd.to_datetime(apart_time['Date'])
weight = pd.read_csv('weight.csv',encoding = 'cp949')

# %% [markdown]
# # Program

# %%
dong = input('행정동 :')
house = input('단지 :')

time_price = apart_time.query('행정동 == @dong and 단지 == @house and Date < "2020-04-01" ')[['Date','price']].set_index('Date')
time_price.plot(figsize = (15,6))
plt.show()

split_date = pd.Timestamp('12-31-2018')
train_price = time_price.loc[:split_date, ['price']]
test_price = time_price.loc[split_date:, ['price']]

plt.figure(figsize=(15,6))
plt.plot(train_price)
plt.plot(test_price)
plt.legend(['train', 'test'])
plt.show()

# ARIMA 모델 만들기
arima_model = auto_arima(train_price, start_p = 0, d = 1, start_q = 0,
                         max_p = 5, max_d = 5, max_q = 5, start_P = 0,
                         D = 1, start_Q = 0, max_P = 5, max_D = 5,
                         max_Q = 5, m = 12, seasonal = True,
                         error_action = 'warn', trace = True,
                         supress_warnings = True, stepwise = True,
                         random_state = 20, n_fits = 50)

arima_model.summary()

# 시계열 분석을 활용한 예측값
prediction = pd.DataFrame(arima_model.predict(n_periods = len(test_price)),index = test_price.index)
prediction.columns = ['predicted_price']

# #가중치 적용
# w = weight.query('행정동 == @dong')
# w_2019_1 = w.iloc[:,1]
# w_2019_2 = w.iloc[:,2]
# w_2019_3 = w.iloc[:,3]
# w_2019_4 = w.iloc[:,4]
# w_2020_1 = w.iloc[:,5]

# prediction = prediction.reset_index()

# q1_19 = prediction.query('Date < "2019-04-01"').iloc[:,1]*w_2019_1
# q1_19 = q1_19.to_frame()

# q2_19 = prediction.query('Date < "2019-07-01" and "2019-04-01" <= Date').iloc[:,1]*w_2019_2
# q2_19 = q2_19.to_frame()

# q3_19 = prediction.query('Date < "2019-10-01" and "2019-07-01" <= Date').iloc[:,1]*w_2019_3
# q3_19 = q3_19.to_frame()

# q4_19 = prediction.query('Date < "2020-01-01" and "2019-10-01" <= Date').iloc[:,1]*w_2019_4
# q4_19 = q4_19.to_frame()

# q1_20 = prediction.query('Date >= "2020-01-01"').iloc[:,1]*w_2020_1
# q1_20 = q1_20.to_frame()


# p_w = pd.concat([q1_19, q2_19, q3_19, q4_19, q1_20])
# prediction['predicted_price'] = p_w['predicted_price']
# prediction = prediction.set_index('Date')
# prediction

# 예측값 시각화
plt.figure(figsize = (8,5))
plt.plot(train_price,label = 'Training')
plt.plot(test_price,label = 'Test')
plt.plot(prediction,label = 'Predicted')
plt.legend(loc = 'Left corner')
plt.show()

# 정확도
from sklearn.metrics import r2_score
test_price['predicted_price'] = prediction
r2_score(test_price['price'],test_price['predicted_price'])
# Out:
# 행정동 :상계제1동
# 단지 :두산
# Performing stepwise search to minimize aic
# Fit ARIMA(0,1,0)x(0,1,0,12) [intercept=True]; AIC=803.393, BIC=808.231, Time=0.021 seconds
# Fit ARIMA(1,1,0)x(1,1,0,12) [intercept=True]; AIC=777.674, BIC=787.350, Time=0.279 seconds
# Fit ARIMA(0,1,1)x(0,1,1,12) [intercept=True]; AIC=750.341, BIC=760.016, Time=0.444 seconds
# Near non-invertible roots for order (0, 1, 1)(0, 1, 1, 12); setting score to inf (at least one inverse root too close to the border of the unit circle: 0.998)
# Fit ARIMA(0,1,0)x(0,1,0,12) [intercept=False]; AIC=801.394, BIC=803.813, Time=0.015 seconds
# Fit ARIMA(1,1,0)x(0,1,0,12) [intercept=True]; AIC=786.826, BIC=794.083, Time=0.066 seconds
# Fit ARIMA(1,1,0)x(2,1,0,12) [intercept=True]; AIC=772.658, BIC=784.752, Time=0.996 seconds
# Fit ARIMA(1,1,0)x(3,1,0,12) [intercept=True]; AIC=773.529, BIC=788.042, Time=1.908 seconds
# Fit ARIMA(1,1,0)x(2,1,1,12) [intercept=True]; AIC=771.847, BIC=786.360, Time=1.194 seconds
# Near non-invertible roots for order (1, 1, 0)(2, 1, 1, 12); setting score to inf (at least one inverse root too close to the border of the unit circle: 0.996)
# C:\Users\Lee_HyeonJun\Anaconda3\lib\site-packages\statsmodels\base\model.py:568: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   "Check mle_retvals", ConvergenceWarning)
# Fit ARIMA(1,1,0)x(1,1,1,12) [intercept=True]; AIC=769.844, BIC=781.938, Time=0.838 seconds
# Near non-invertible roots for order (1, 1, 0)(1, 1, 1, 12); setting score to inf (at least one inverse root too close to the border of the unit circle: 1.000)
# Fit ARIMA(1,1,0)x(3,1,1,12) [intercept=True]; AIC=774.973, BIC=791.905, Time=3.774 seconds
# Fit ARIMA(0,1,0)x(2,1,0,12) [intercept=True]; AIC=786.044, BIC=795.719, Time=0.629 seconds
# Fit ARIMA(2,1,0)x(2,1,0,12) [intercept=True]; AIC=768.534, BIC=783.047, Time=1.163 seconds
# Fit ARIMA(2,1,0)x(1,1,0,12) [intercept=True]; AIC=773.724, BIC=785.818, Time=0.381 seconds
# Fit ARIMA(2,1,0)x(3,1,0,12) [intercept=True]; AIC=769.490, BIC=786.422, Time=1.947 seconds
# Fit ARIMA(2,1,0)x(2,1,1,12) [intercept=True]; AIC=769.118, BIC=786.050, Time=1.645 seconds
# Near non-invertible roots for order (2, 1, 0)(2, 1, 1, 12); setting score to inf (at least one inverse root too close to the border of the unit circle: 0.995)
# Fit ARIMA(2,1,0)x(1,1,1,12) [intercept=True]; AIC=767.129, BIC=781.642, Time=0.620 seconds
# Fit ARIMA(2,1,0)x(0,1,1,12) [intercept=True]; AIC=765.145, BIC=777.239, Time=0.351 seconds
# Fit ARIMA(2,1,0)x(0,1,0,12) [intercept=True]; AIC=784.769, BIC=794.444, Time=0.156 seconds
# C:\Users\Lee_HyeonJun\Anaconda3\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:1006: UserWarning: Non-invertible starting seasonal moving average Using zeros as starting parameters.
#   warn('Non-invertible starting seasonal moving average'
# Fit ARIMA(2,1,0)x(0,1,2,12) [intercept=True]; AIC=767.129, BIC=781.642, Time=1.067 seconds
# C:\Users\Lee_HyeonJun\Anaconda3\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:1006: UserWarning: Non-invertible starting seasonal moving average Using zeros as starting parameters.
#   warn('Non-invertible starting seasonal moving average'
# Fit ARIMA(2,1,0)x(1,1,2,12) [intercept=True]; AIC=769.091, BIC=786.023, Time=1.759 seconds
# Fit ARIMA(1,1,0)x(0,1,1,12) [intercept=True]; AIC=768.192, BIC=777.867, Time=0.278 seconds
# Fit ARIMA(3,1,0)x(0,1,1,12) [intercept=True]; AIC=756.105, BIC=770.618, Time=0.700 seconds
# Near non-invertible roots for order (3, 1, 0)(0, 1, 1, 12); setting score to inf (at least one inverse root too close to the border of the unit circle: 1.000)
# C:\Users\Lee_HyeonJun\Anaconda3\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:975: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
# Fit ARIMA(2,1,1)x(0,1,1,12) [intercept=True]; AIC=753.259, BIC=767.772, Time=0.809 seconds
# Near non-invertible roots for order (2, 1, 1)(0, 1, 1, 12); setting score to inf (at least one inverse root too close to the border of the unit circle: 0.998)
# Fit ARIMA(1,1,1)x(0,1,1,12) [intercept=True]; AIC=751.514, BIC=763.608, Time=0.506 seconds
# Near non-invertible roots for order (1, 1, 1)(0, 1, 1, 12); setting score to inf (at least one inverse root too close to the border of the unit circle: 0.998)
# Fit ARIMA(3,1,1)x(0,1,1,12) [intercept=True]; AIC=753.788, BIC=770.720, Time=0.951 seconds
# Near non-invertible roots for order (3, 1, 1)(0, 1, 1, 12); setting score to inf (at least one inverse root too close to the border of the unit circle: 1.000)
# Total fit time: 22.502 seconds
# C:\Users\Lee_HyeonJun\Anaconda3\lib\site-packages\statsmodels\base\model.py:568: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   "Check mle_retvals", ConvergenceWarning)
# C:\Users\Lee_HyeonJun\Anaconda3\lib\site-packages\ipykernel_launcher.py:69: MatplotlibDeprecationWarning: Unrecognized location 'Left corner'. Falling back on 'best'; valid locations are
# 	best
# 	upper right
# 	upper left
# 	lower left
# 	lower right
# 	right
# 	center left
# 	center right
# 	lower center
# 	upper center
# 	center
# This will raise an exception in 3.3.
# 0.7600483491291465

# %%
w = weight.query('행정동 == @dong')

# %%
prediction['weight'] = [0.022868,0.022868,0.022868,0.022868,0.022868,0.022868,
                        0.021732,0.021732,0.021732,0.022868,0.022868,0.022868,
                        0.022868,0.022868,0.022868]

# %%
prediction['predicted_price_w'] = prediction['predicted_price'] + prediction['predicted_price']*prediction['weight']

# %%
prediction
# Out:
#             predicted_price    weight  predicted_price_w
# Date
# 2019-01-01       551.947590  0.022868         564.569528
# 2019-02-01       562.980363  0.022868         575.854598
# 2019-03-01       558.710040  0.022868         571.486621
# 2019-04-01       570.712031  0.022868         583.763073
# 2019-05-01       562.331928  0.022868         575.191335
# 2019-06-01       578.703722  0.022868         591.937518
# 2019-07-01       580.676755  0.021732         593.296022
# 2019-08-01       579.361314  0.021732         591.951994
# 2019-09-01       592.136278  0.021732         605.004584
# 2019-10-01       603.485787  0.022868         617.286300
# 2019-11-01       597.053583  0.022868         610.707005
# 2019-12-01       603.759152  0.022868         617.565916
# 2020-01-01       616.997321  0.022868         631.106816
# 2020-02-01       628.908193  0.022868         643.290066
# 2020-03-01       625.515969  0.022868         639.820269

# %%
prediction = prediction['predicted_price_w'].reset_index().set_index('Date')

# %%
# 예측값 시각화
plt.figure(figsize = (8,5))
plt.plot(train_price,label = 'Training')
plt.plot(test_price,label = 'Test')
plt.plot(prediction,label = 'Predicted')
plt.legend(loc = 'Left corner')
plt.show()

# 정확도
from sklearn.metrics import r2_score
test_price['predicted_price'] = prediction
r2_score(test_price['price'],test_price['predicted_price'])
# Out:
# C:\Users\Lee_HyeonJun\Anaconda3\lib\site-packages\ipykernel_launcher.py:6: MatplotlibDeprecationWarning: Unrecognized location 'Left corner'. Falling back on 'best'; valid locations are
# 	best
# 	upper right
# 	upper left
# 	lower left
# 	lower right
# 	right
# 	center left
# 	center right
# 	lower center
# 	upper center
# 	center
# This will raise an exception in 3.3.
# 0.6104998831234606
